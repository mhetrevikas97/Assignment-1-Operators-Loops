# %%
x = 0
y = 1
for Num in range(0, 50):
    if(Num == 1):
        Next = Num
    else:
         Next = x + y
         x = y
         y = Next
    if (Num ==0):
            pass
    if y>50:
            break
        
    print(Next)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21
# 34
